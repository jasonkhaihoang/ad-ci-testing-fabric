# %%
# Gate 2 prep — deps
# !pip install vd-dbt-fabricspark==1.9.15 -q

# %%
# Gate 2 — SHALLOW CLONE
# Placeholders substituted by inject_notebook.py before run
branch = '{{BRANCH}}'
head_sha = '{{HEAD_SHA}}'
workspace_id = '{{EPHEMERAL_WORKSPACE_ID}}'
lakehouse_id = '{{EPHEMERAL_LAKEHOUSE_ID}}'

# %%
# Gates 2/3/4 — build + unit tests + data tests
print('CI verification notebook — stub')
